# %%
import pandas as pd

# %%
prov_info = pd.read_csv(r'/Users/amanchopra/Documents/Work/Aarete/Provider Transparency Project/prov_data.csv')
prov_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1566 entries, 0 to 1565
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Provider               1566 non-null   object
#  1   Zip Code               1566 non-null   int64
#  2   CPT                    1566 non-null   object
#  3   Service                1566 non-null   object
#  4   Cash Price             1565 non-null   object
#  5   Insurance Price        1253 non-null   object
#  6   Comparison Statistics  1517 non-null   object
#  7   TQH Name               1565 non-null   object
#  8   TQH Address            0 non-null      float64
# dtypes: float64(1), int64(1), object(7)
# memory usage: 110.2+ KB

# %%
prov_info[prov_info['Provider'] == 'KINDRED HOSPITAL BALDWIN PARK']
# Out:
#                          Provider  Zip Code          CPT  \
# 40  KINDRED HOSPITAL BALDWIN PARK     91706  HCPCS 10061
# 41  KINDRED HOSPITAL BALDWIN PARK     91706  HCPCS 36415
# 42  KINDRED HOSPITAL BALDWIN PARK     91706  HCPCS 84591
# 43  KINDRED HOSPITAL BALDWIN PARK     91706  HCPCS 29881
# 44  KINDRED HOSPITAL BALDWIN PARK     91706  HCPCS 70491
# 45  KINDRED HOSPITAL BALDWIN PARK     91706  HCPCS 73140
# 46  KINDRED HOSPITAL BALDWIN PARK     91706  HCPCS 45391
# 47  KINDRED HOSPITAL BALDWIN PARK     91706  HCPCS 43239
# 48  KINDRED HOSPITAL BALDWIN PARK     91706  HCPCS 73600
# 49  KINDRED HOSPITAL BALDWIN PARK     91706  HCPCS 83519
#
#                                               Service Cash Price  \
# 40                           Drainage Of Skin Abscess    $649.80
# 41                    Venipuncture (Blood Collection)     $16.20
# 42                                  Vitamin B-6 Level     $52.56
# 43                Knee Arthroscopic Cartilage Removal  $3,339.00
# ...

# %%
prov_info[prov_info['Insurance Price'].isna()]
# Out:
#                                Provider  Zip Code          CPT  \
# 41        KINDRED HOSPITAL BALDWIN PARK     91706  HCPCS 36415
# 62           MONROVIA MEMORIAL HOSPITAL     91016    MSDRG 392
# 64           MONROVIA MEMORIAL HOSPITAL     91016  HCPCS 66984
# 65           MONROVIA MEMORIAL HOSPITAL     91016    MSDRG 743
# 81         STAR VIEW ADOLESCENT - P H F     90505    MSDRG 313
# ...                                 ...       ...          ...
# 1539  HILLSDALE COMMUNITY HEALTH CENTER     49242  HCPCS 72130
# 1540  HILLSDALE COMMUNITY HEALTH CENTER     49242  HCPCS 86359
# 1541  HILLSDALE COMMUNITY HEALTH CENTER     49242  HCPCS 73592
# 1545  HILLSDALE COMMUNITY HEALTH CENTER     49242  HCPCS 86747
# 1555               DMC SURGERY HOSPITAL     48071  HCPCS 72070
#
#                                                 Service  Cash Price  \
# 41                      Venipuncture (Blood Collection)      $16.20
# 62    Esophagitis, Gastroenteritis And Miscellaneous...  $13,220.14
# ...
